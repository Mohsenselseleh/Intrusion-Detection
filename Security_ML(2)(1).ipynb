# %%
import pandas as pd 
import numpy as np
mydata= pd.read_csv("C:/Users/Mohsen/Desktop/Wednesday-workingHours.pcap_ISCX.csv")
#Constructing DataFrame
mydata=pd.DataFrame(data=mydata)    
# Create a reproducible sample using random_state
mydata = mydata.sample(n = 1000, random_state = 1)

# %%
# IS THERE ANY MISSING DATA?
mydata.isnull().sum()
# Out:
#  Destination Port              0
#  Flow Duration                 0
#  Total Fwd Packets             0
#  Total Backward Packets        0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      0
#  Idle Std                      0
#  Idle Max                      0
#  Idle Min                      0
# Label                          0
# Length: 79, dtype: int64

# %%
mydata = mydata.replace(['BENIGN'],'0')
mydata=mydata.replace(['DoS Hulk'],'1')
mydata=mydata.replace(['DoS GoldenEye'],'1')
mydata=mydata.replace(['DoS slowloris'],'1')
mydata=mydata.replace(['DoS Slowhttptest'],'1')
mydata=mydata.replace(['Heartbleed'],'1')

# %%
mydata.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count        1000.000000    1.000000e+03         1000.000000
# mean         5314.911000    2.713930e+07            6.119000
# std         15495.989176    4.260360e+07           13.994738
# min            21.000000    1.000000e+00            1.000000
# 25%            53.000000    2.147500e+02            2.000000
# 50%            80.000000    5.019950e+04            2.000000
# 75%           443.000000    6.785736e+07            7.000000
# max         61674.000000    1.199921e+08          247.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count              1000.000000                  1000.000000
# mean                  5.567000                   806.090000
# std                  19.083965                  4212.244067
# min                   0.000000                     0.000000
# 25%                   1.000000                    12.000000
# ...

# %%
mydata.head(10)
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 560699                 53             213                   2
# 538462                 53           31082                   4
# 626316                 53             295                   2
# 310282                 80           24610                   2
# 485771                 53        19177137                   2
# 676471                 53           31367                   2
# 144377                 80               3                   2
# 261448                 80        98196159                   6
# 282145                 80        85745147                   8
# 108045                 80           98509                   3
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 560699                        2                          144
# 538462                        4                          188
# 626316                        2                          102
# ...

# %%
mydata=mydata.dropna()

# %%
X = mydata.drop('Label', 1)
y = mydata['Label']

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.decomposition import PCA
pca = PCA()
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=2, random_state=0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
print( accuracy_score(y_test, y_pred))
# Out:
# [[115   0]
#  [ 45  40]]
# [[115   0]
#  [ 45  40]]
# 0.775

# %%
# Initialize the logistic regression model
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(max_iter=2500)

# Train the model
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test) # Predictions
y_true = y_test # True values
# Measure accuracy
from sklearn import metrics
from sklearn.metrics import accuracy_score
import numpy as np
print("Train accuracy:", np.round(accuracy_score(y_train,clf.predict(X_train)), 2))
print("Test accuracy:", np.round(accuracy_score(y_true, y_pred), 2))
# Out:
# Train accuracy: 0.84
# Test accuracy: 0.78

# %%
# Neural Network
# Neural Network
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(8,8,8), activation='relu', solver='adam', max_iter=500)
model = mlp.fit(X_train,y_train)
predict_train = mlp.predict(X_train)
predict_test = mlp.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_train,predict_train))
print(classification_report(y_train,predict_train))
# Area under curve
print("area under curve (auc): ", metrics.roc_auc_score(y_test, y_pred))
# Out:
# [[492  36]
#  [105 167]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       528
#            1       0.82      0.61      0.70       272
#
#     accuracy                           0.82       800
#    macro avg       0.82      0.77      0.79       800
# weighted avg       0.82      0.82      0.82       800
#
# area under curve (auc):  0.7398976982097187
